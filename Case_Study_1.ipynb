# %% [markdown]
# <a href="https://colab.research.google.com/github/MayuriD09/Central-Neuropathic-Pain/blob/main/Case_Study_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #
#
# #### Predicting Central Neuropathic Pain (CNP) in people with Spinal Cord Injury (SCI) from Electroencephalogram (EEG) data.
#
# * CNP is pain in response to non-painful stimuli, episodic (electric shock), “pins and needles”, numbness
# * There is currently no treatment, only prevention
# * Preventative medications have strong side-effects
# * Predicting whether a patient is likely to develop pain is useful for selective treatment
#
# #### Task
# Your task is to devise a feature engineering strategy which, in combination with a classifier of your choice, optizimes prediction accuracy.
#
# #### Data
# The data is preprocessed brain EEG data from SCI patients recorded while resting with eyes closed (EC) and eyes opened (EO).
# * 48 electrodes recording electrical activity of the brain at 250 Hz
# * 2 classes: subject will / will not develop neuropathic pain within 6 months
# * 18 subjects: 10 developed pain and 8 didn’t develop pain
# * the data has already undergone some preprocessing
#   * Signal denoising and normalization
#   * Temporal segmentation
#   * Frequency band power estimation
#   * Normalization with respect to total band power
#   * Features include normalized alpha, beta, theta band power while eyes closed, eyes opened, and taking the ratio of eo/ec.
# * the data is provided in a single table ('data.csv') consisting of
#   * 180 rows (18 subjects x 10 repetitions), each containing
#   * 432 columns (9 features x 48 electrodes)
#   * rows are in subject major order, i.e. rows 0-9 are all samples from subject 0, rows 10-19 all samples from subject 1, etc.
#   * columns are in feature_type major order, i.e. columns 0-47 are alpha band power, eyes closed, electrodes 0-48
#   * feature identifiers for all columns are stored in 'feature_names.csv'
#   * 'labels.csv' defines the corresponding class (0 or 1) to each row in data.csv
#
# #### Objective Measure
# Leave one subject out cross-validation accuracy, sensitivity and specificity.
#
# #### Report
# Report on your feature engineering pipeline, the classifier used to evaluate performance, and the performance as mean and standard deviation of accuracy, sensitivity and specificity across folds. Give evidence for why your strategy is better than others.

# %%
import csv
import numpy as np

from matplotlib import pyplot as plt

# %%
# load data
# rows in X are subject major order, i.e. rows 0-9 are all samples from subject 0, rows 10-19 all samples from subject 1, etc.
# columns in X are in feature_type major order, i.e. columns 0-47 are alpha band power, eyes closed, electrodes 0-48
# feature identifiers for all columns in X are stored in feature_names.csv
X = np.loadtxt('data.csv', delimiter=',') 
y = np.loadtxt('labels.csv', delimiter=',')
with open('feature_names.csv') as f:
    csvreader = csv.reader(f, delimiter=',')
    feature_names = [row for row in csvreader][0]

# %%
# plotting data in 2D with axes sampled 
# a) at random 
# b) from same electrode
# c) from same feature type
num_features = 9
num_electrodes = 48

# a) indices drawn at random
i0, i1 = np.random.randint(0, X.shape[1], size=2)

# b) same electrode, different feature (uncomment lines below)
#f0, f1 = np.random.randint(0, num_features, size=2)
#e = np.random.randint(0, num_electrodes)
#i0, i1 = f0*num_electrodes + e, f1*num_electrodes + e

# b) same feature, different electrode (uncomment lines below)
#f = np.random.randint(0, num_features)
#e0, e1 = np.random.randint(0, num_electrodes, size=2)
#i0, i1 = f*num_electrodes + e0, f*num_electrodes + e1

fig, axes = plt.subplots(1, 3, figsize=(24, 6))
colors = ['blue', 'red']

# select features i0, i1 and separate by class
X00, X01 = X[y==0][:,i0], X[y==1][:,i0]
X10, X11 = X[y==0][:,i1], X[y==1][:,i1]
# plot cumulative distribution of feature i0 separate for each class
axes[0].hist(X00, bins=20, label='y=0, '+ feature_names[i0], density=True, alpha=0.5)
axes[0].hist(X01, bins=20, label='y=1, '+ feature_names[i0], density=True, alpha=0.5)
axes[0].hist(X10, bins=20, label='y=0, '+ feature_names[i1], density=True, alpha=0.5)
axes[0].hist(X11, bins=20, label='y=1, '+ feature_names[i1], density=True, alpha=0.5)
axes[0].set_title('histograms')
axes[0].legend()
axes[1].plot(np.sort(X00), np.linspace(0,1,X00.shape[0]), label='y=0, '+ feature_names[i0], alpha=0.5)
axes[1].plot(np.sort(X01), np.linspace(0,1,X01.shape[0]), label='y=1, '+ feature_names[i0], alpha=0.5)
axes[1].plot(np.sort(X10), np.linspace(0,1,X10.shape[0]), label='y=0, '+ feature_names[i1], alpha=0.5)
axes[1].plot(np.sort(X11), np.linspace(0,1,X11.shape[0]), label='y=1, '+ feature_names[i1], alpha=0.5)
axes[1].set_title('empirical cumulative distribution functions')
axes[1].legend()
axes[2].scatter(X00, X10, label='y=0')
axes[2].scatter(X01, X11, label='y=1')
axes[2].set_xlabel(feature_names[i0])
axes[2].set_ylabel(feature_names[i1])
axes[2].set_title('scatter plot')
axes[2].legend()

# %% [markdown]
# ### Import Libraries ###

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import LeaveOneGroupOut
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_regression
from sklearn.linear_model import RidgeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Hyperparameter Tuning ###

# %%
pipe_pca = Pipeline([('classifier' , RandomForestClassifier())])
pipe_skb = Pipeline([('classifier' , RandomForestClassifier())])

pca = PCA(0.99)
pca.fit(X)
X_pca = pca.transform(X)

skbest = SelectKBest(mutual_info_regression, k=200)
X_skb = skbest.fit_transform(X, y)


# Create param grid.
param_grid = [
    {
        'classifier' : [LogisticRegression()],
        'classifier__penalty' : ['l1', 'l2'],
        'classifier__max_iter' : [1000, 500, 200, 100],
        'classifier__C' : [100,10,5,1,0.1,0.01],
        'classifier__solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
    },    
    {
        'classifier' : [RandomForestClassifier()],
        'classifier__n_estimators' : list(range(10,101,10)),
        'classifier__max_features' : ['auto', 'sqrt', 'log2']
    },    
    {
        'classifier' : [RidgeClassifier()],
        'classifier__alpha' : list(np.array(range(1,11))/10.0),
        'classifier__solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']
    }
]

# Create grid search object
clf_pca = GridSearchCV(pipe_pca, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)
clf_skb = GridSearchCV(pipe_skb, param_grid = param_grid, cv = 5, verbose=True, n_jobs=-1)

# Fit on data
best_clf_pca = clf_pca.fit(X_pca, y)
best_clf_skb = clf_skb.fit(X_skb, y)
# Out:
# Fitting 5 folds for each of 340 candidates, totalling 1700 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 280 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 1700 out of 1700 | elapsed:    8.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.0s
# Fitting 5 folds for each of 340 candidates, totalling 1700 fits
# [Parallel(n_jobs=-1)]: Done 512 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 1512 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 1700 out of 1700 | elapsed:   11.2s finished

# %%
print(best_clf_pca.best_params_)
print(best_clf_pca.best_score_)

print(best_clf_skb.best_params_)
print(best_clf_skb.best_score_)
# Out:
# {'classifier': LogisticRegression(C=10, max_iter=1000, solver='newton-cg'), 'classifier__C': 10, 'classifier__max_iter': 1000, 'classifier__penalty': 'l2', 'classifier__solver': 'newton-cg'}
# 0.861111111111111
# {'classifier': RidgeClassifier(alpha=0.5, solver='lsqr'), 'classifier__alpha': 0.5, 'classifier__solver': 'lsqr'}
# 0.9111111111111111

# %%
# Calculates sensitivity and specificity
def calculate_Se_Sp(predictedOutput, actualOutput):
    tp, fn, fp, tn  = confusion_matrix(actualOutput,predictedOutput,labels=[0,1]).ravel()
    se = 1
    sp = 1
    if (tp+fn) != 0:
        se = tp / (tp+fn)
    if (tn+fp) != 0:
        sp = tn / (tn+fp)
    return se, sp


def cross_validate_leave_one_out_PCA(model, X, y, percent):
    logo = LeaveOneGroupOut()
    y_test_list = []
    output_list = []
    ret = []
    se_list = []
    sp_list = []
    performance = []
    
    groups = []
    for i in range(180):
        groups.append(int(i/10)+1)
    
    print(model)
    pca = PCA(n_components=percent)
    
    for train_index, test_index in logo.split(X, y, groups):
        X_train, X_test = np.array(X[train_index]), np.array(X[test_index])
        y_train, y_test = np.array(y[train_index]), np.array(y[test_index])

        pca.fit(X_train)
        X_train_pca = pca.transform(X_train)
        X_test_pca = pca.transform(X_test)
        
        clf = model.fit(X_train_pca, y_train)
        output = model.predict(X_test_pca)
        y_test_list.append(y_test)
        output_list.append(output)
        performance.append(model.score(X_test_pca, y_test))
        se, sp = calculate_Se_Sp(output, y_test)
        se_list.append(se)
        sp_list.append(sp)

    auc = metrics.roc_auc_score(y_test_list, output_list)
    ret = [ round(np.mean(performance), 4), round(np.mean(se_list), 4), round(np.mean(sp_list), 4), round(auc, 4) ]
    
    return ret

def cross_validate_leave_one_out_SKB(model, X, y, n_features):
    logo = LeaveOneGroupOut()
    y_test_list = []
    output_list = []
    ret = []
    se_list = []
    sp_list = []
    performance = []
    
    print(model)
    groups = []
    for i in range(180):
        groups.append(int(i/10)+1)
        
    for train_index, test_index in logo.split(X, y, groups):
        X_train, X_test = np.array(X[train_index]), np.array(X[test_index])
        y_train, y_test = np.array(y[train_index]), np.array(y[test_index])

        skbest = SelectKBest(k=n_features)
        train_X_reduced = skbest.fit_transform(X_train, y_train)
        test_X_reduced = skbest.transform(X_test)
        
        
        clf = model.fit(train_X_reduced, y_train)
        output = model.predict(test_X_reduced)
        y_test_list.append(y_test)
        output_list.append(output)
        se, sp = calculate_Se_Sp(output, y_test)
        se_list.append(se)
        sp_list.append(sp)
        performance.append(model.score(test_X_reduced, y_test))

    auc = metrics.roc_auc_score(y_test_list, output_list)
    ret = [ round(np.mean(performance), 4), round(np.mean(se_list), 4), round(np.mean(sp_list), 4), round(auc, 4) ]
    
    return ret

def plot_graph(y,title):
    plt.xlim([10, len(y)+10])
    plt.ylim([0.0, 1.05])
    plt.yticks(np.arange(0, 1, step=0.1))
    plt.grid(True,axis='y')
    plt.title(title)
    #plot max value
    xmax = np.argmax(y)
    ymax = y[xmax]
    text= "x={:.3f}, y={:.3f}".format(xmax+10, ymax)
    bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
    arrowprops=dict(arrowstyle="->",connectionstyle="angle,angleA=0,angleB=60")
    kw = dict(xycoords='data',textcoords="axes fraction",
              arrowprops=arrowprops, bbox=bbox_props, ha="right", va="top")
    plt.annotate(text, xy=(xmax, ymax), xytext=(0.94,0.96), **kw)
    plt.plot(range(10,len(y)+10),y)
    plt.show()

# %%
# Standardise the data
x = StandardScaler().fit_transform(X)

results_PCA_LR = np.array([])
results_PCA_RC = np.array([])

model = best_clf_pca.best_params_['classifier']
print("Model Selected: ", model)

for num_features in range(10,170):
    print("\nNum_features :", num_features)
    
    # Run cross-validation on model with PCA fearture extraction.
    result_LR = cross_validate_leave_one_out_PCA(model, X, y, num_features)
    print("Result : ", result_LR)
    results_PCA_LR = np.append(results_PCA_LR,np.array(result_LR))
# Out:
# Model Selected:  LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
#
# Num_features : 10
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7167, 0.8556, 0.8611, 0.7138]
#
# Num_features : 11
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7222, 0.8722, 0.85, 0.7162]
#
# Num_features : 12
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7167, 0.8667, 0.85, 0.7112]
#
# Num_features : 13
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7111, 0.8611, 0.85, 0.7062]
#
# Num_features : 14
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7056, 0.8556, 0.85, 0.7012]
#
# Num_features : 15
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6889, 0.8389, 0.85, 0.6862]
#
# Num_features : 16
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6889, 0.8444, 0.8444, 0.685]
#
# Num_features : 17
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6944, 0.85, 0.8444, 0.69]
#
# Num_features : 18
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6833, 0.8444, 0.8389, 0.6788]
#
# Num_features : 19
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6778, 0.8444, 0.8333, 0.6725]
#
# Num_features : 20
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6667, 0.85, 0.8167, 0.6588]
#
# Num_features : 21
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.6556, 0.8444, 0.8111, 0.6475]
#
# Num_features : 22
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7222, 0.8778, 0.8444, 0.715]
#
# Num_features : 23
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7111, 0.8556, 0.8556, 0.7075]
#
# Num_features : 24
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7278, 0.8778, 0.85, 0.7213]
#
# Num_features : 25
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7278, 0.8722, 0.8556, 0.7225]
#
# Num_features : 26
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7167, 0.8611, 0.8556, 0.7125]
#
# Num_features : 27
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7778, 0.9, 0.8778, 0.7725]
#
# Num_features : 28
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7889, 0.9056, 0.8833, 0.7838]
#
# Num_features : 29
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7722, 0.8889, 0.8833, 0.7688]
#
# Num_features : 30
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.75, 0.8944, 0.8556, 0.7425]
#
# Num_features : 31
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7722, 0.9056, 0.8667, 0.765]
#
# Num_features : 32
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7833, 0.9056, 0.8778, 0.7775]
#
# Num_features : 33
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7889, 0.9, 0.8889, 0.785]
#
# Num_features : 34
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7778, 0.8944, 0.8833, 0.7737]
#
# Num_features : 35
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.7889, 0.9056, 0.8833, 0.7837]
#
# Num_features : 36
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8111, 0.9111, 0.9, 0.8075]
#
# Num_features : 37
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 38
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8412]
#
# Num_features : 39
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 40
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8167, 0.9167, 0.9, 0.8125]
#
# Num_features : 41
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9278, 0.9111, 0.835]
#
# Num_features : 42
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8611, 0.9389, 0.9222, 0.8575]
#
# Num_features : 43
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 44
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9389, 0.9056, 0.8387]
#
# Num_features : 45
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 46
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8611, 0.9333, 0.9278, 0.8588]
#
# Num_features : 47
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8778, 0.95, 0.9278, 0.8738]
#
# Num_features : 48
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8722, 0.9556, 0.9167, 0.8662]
#
# Num_features : 49
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8667, 0.9444, 0.9222, 0.8625]
#
# Num_features : 50
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9222, 0.9278, 0.8488]
#
# Num_features : 51
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 52
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8412]
#
# Num_features : 53
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9222, 0.9167, 0.8362]
#
# Num_features : 54
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 55
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 56
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 57
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9333, 0.9111, 0.84]
#
# Num_features : 58
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9444, 0.9111, 0.85]
#
# Num_features : 59
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9389, 0.9167, 0.8512]
#
# Num_features : 60
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 61
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9278, 0.9111, 0.835]
#
# Num_features : 62
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 63
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 64
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9333, 0.9111, 0.84]
#
# Num_features : 65
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9333, 0.9111, 0.84]
#
# Num_features : 66
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 67
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9333, 0.9056, 0.8338]
#
# Num_features : 68
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8278, 0.9278, 0.9, 0.8225]
#
# Num_features : 69
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8167, 0.9278, 0.8889, 0.81]
#
# Num_features : 70
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8111, 0.9167, 0.8944, 0.8062]
#
# Num_features : 71
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8222, 0.9222, 0.9, 0.8175]
#
# Num_features : 72
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8167, 0.9222, 0.8944, 0.8112]
#
# Num_features : 73
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8222, 0.9278, 0.8944, 0.8163]
#
# Num_features : 74
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8, 0.9167, 0.8833, 0.7938]
#
# Num_features : 75
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8167, 0.9222, 0.8944, 0.8112]
#
# Num_features : 76
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8111, 0.9167, 0.8944, 0.8062]
#
# Num_features : 77
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8111, 0.9167, 0.8944, 0.8062]
#
# Num_features : 78
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8333, 0.9278, 0.9056, 0.8288]
#
# Num_features : 79
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 80
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9222, 0.9167, 0.8362]
#
# Num_features : 81
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8389, 0.9222, 0.9167, 0.8362]
#
# Num_features : 82
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 83
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 84
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 85
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 86
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 87
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 88
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 89
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 90
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 91
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 92
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 93
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 94
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 95
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 96
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 97
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 98
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 99
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 100
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 101
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 102
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 103
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9333, 0.9167, 0.8462]
#
# Num_features : 104
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 105
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 106
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 107
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 108
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 109
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 110
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 111
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 112
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 113
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 114
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8444, 0.9278, 0.9167, 0.8413]
#
# Num_features : 115
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 116
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 117
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 118
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 119
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 120
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 121
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 122
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 123
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 124
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 125
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9278, 0.9278, 0.8538]
#
# Num_features : 126
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 127
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.85, 0.9278, 0.9222, 0.8475]
#
# Num_features : 128
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 129
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 130
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 131
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 132
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 133
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 134
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 135
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 136
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 137
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 138
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 139
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 140
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 141
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 142
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 143
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 144
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 145
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 146
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 147
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 148
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 149
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 150
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 151
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 152
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 153
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 154
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 155
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 156
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 157
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 158
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 159
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 160
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 161
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 162
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 163
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 164
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 165
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 166
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 167
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 168
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]
#
# Num_features : 169
# LogisticRegression(C=10, max_iter=1000, solver='newton-cg')
# Result :  [0.8556, 0.9333, 0.9222, 0.8525]

# %%
y_value = np.reshape(results_PCA_LR,(160,4))

plot_graph(y_value[:,0],"Results with PCA : Accuracy")
plot_graph(y_value[:,1],"Results with PCA : Specificity")
plot_graph(y_value[:,2],"Results with PCA : Sensitivity")
plot_graph(y_value[:,3],"Results with PCA : AUC")

# %%
results_SBK_LR = np.array([])
results_SBK_RC = np.array([])

    
model = best_clf_skb.best_params_['classifier']
print("Model Selected: ", model)
for num_features in range(10,201):
    print("\nNum_features :", num_features)

    # Run cross-validation on model with SelectKBest fearture selection.
    result_LR = cross_validate_leave_one_out_SKB(model, X, y, num_features)
    print("Results : ", result_LR)
    results_SBK_LR = np.append(results_SBK_LR,np.array(result_LR))
# Out:
# Model Selected:  RidgeClassifier(alpha=0.5, solver='lsqr')
#
# Num_features : 10
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.6944, 0.8889, 0.8056, 0.6813]
#
# Num_features : 11
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.6833, 0.8833, 0.8, 0.67]
#
# Num_features : 12
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7, 0.9, 0.8, 0.685]
#
# Num_features : 13
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7167, 0.9111, 0.8056, 0.7012]
#
# Num_features : 14
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7389, 0.9222, 0.8167, 0.7238]
#
# Num_features : 15
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7333, 0.9111, 0.8222, 0.72]
#
# Num_features : 16
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7389, 0.9, 0.8389, 0.7288]
#
# Num_features : 17
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7222, 0.8944, 0.8278, 0.7113]
#
# Num_features : 18
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7, 0.8778, 0.8222, 0.69]
#
# Num_features : 19
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7222, 0.9, 0.8222, 0.71]
#
# Num_features : 20
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7333, 0.8889, 0.8444, 0.725]
#
# Num_features : 21
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7444, 0.9056, 0.8389, 0.7338]
#
# Num_features : 22
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.75, 0.9, 0.85, 0.7413]
#
# Num_features : 23
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7722, 0.9056, 0.8667, 0.765]
#
# Num_features : 24
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7722, 0.9111, 0.8611, 0.7638]
#
# Num_features : 25
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7611, 0.9056, 0.8556, 0.7525]
#
# Num_features : 26
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7833, 0.9167, 0.8667, 0.775]
#
# Num_features : 27
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7833, 0.9278, 0.8556, 0.7725]
#
# Num_features : 28
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.7889, 0.9278, 0.8611, 0.7787]
#
# Num_features : 29
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8, 0.9333, 0.8667, 0.79]
#
# Num_features : 30
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8056, 0.9278, 0.8778, 0.7975]
#
# Num_features : 31
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8056, 0.9278, 0.8778, 0.7975]
#
# Num_features : 32
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9389, 0.8778, 0.8075]
#
# Num_features : 33
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9333, 0.8778, 0.8025]
#
# Num_features : 34
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9444, 0.8722, 0.8062]
#
# Num_features : 35
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9389, 0.8778, 0.8075]
#
# Num_features : 36
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8333, 0.9444, 0.8889, 0.825]
#
# Num_features : 37
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8278, 0.9444, 0.8833, 0.8188]
#
# Num_features : 38
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9333, 0.8833, 0.8087]
#
# Num_features : 39
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 40
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 41
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8278, 0.9333, 0.8944, 0.8212]
#
# Num_features : 42
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8278, 0.9333, 0.8944, 0.8212]
#
# Num_features : 43
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9278, 0.8889, 0.81]
#
# Num_features : 44
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9333, 0.8889, 0.815]
#
# Num_features : 45
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 46
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 47
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9333, 0.8889, 0.815]
#
# Num_features : 48
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9222, 0.8889, 0.805]
#
# Num_features : 49
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9222, 0.8889, 0.805]
#
# Num_features : 50
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9278, 0.8889, 0.81]
#
# Num_features : 51
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9222, 0.8889, 0.805]
#
# Num_features : 52
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9222, 0.8889, 0.805]
#
# Num_features : 53
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8111, 0.9278, 0.8833, 0.8038]
#
# Num_features : 54
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9278, 0.8889, 0.81]
#
# Num_features : 55
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8167, 0.9278, 0.8889, 0.81]
#
# Num_features : 56
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 57
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8056, 0.9222, 0.8833, 0.7988]
#
# Num_features : 58
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8, 0.9167, 0.8833, 0.7938]
#
# Num_features : 59
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8056, 0.9167, 0.8889, 0.8]
#
# Num_features : 60
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8278, 0.9333, 0.8944, 0.8212]
#
# Num_features : 61
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8222, 0.9278, 0.8944, 0.8162]
#
# Num_features : 62
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8333, 0.9389, 0.8944, 0.8262]
#
# Num_features : 63
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8333, 0.9389, 0.8944, 0.8262]
#
# Num_features : 64
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8444, 0.9444, 0.9, 0.8375]
#
# Num_features : 65
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8389, 0.9444, 0.8944, 0.8312]
#
# Num_features : 66
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8444, 0.95, 0.8944, 0.8362]
#
# Num_features : 67
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8444, 0.95, 0.8944, 0.8362]
#
# Num_features : 68
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.85, 0.9444, 0.9056, 0.8438]
#
# Num_features : 69
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.85, 0.9444, 0.9056, 0.8438]
#
# Num_features : 70
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 71
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.85, 0.9389, 0.9111, 0.845]
#
# Num_features : 72
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8444, 0.9444, 0.9, 0.8375]
#
# Num_features : 73
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 74
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.95, 0.9167, 0.8612]
#
# Num_features : 75
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 76
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 77
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 78
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9556, 0.9111, 0.86]
#
# Num_features : 79
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9556, 0.9111, 0.86]
#
# Num_features : 80
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 81
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9611, 0.9167, 0.8712]
#
# Num_features : 82
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9611, 0.9167, 0.8712]
#
# Num_features : 83
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9611, 0.9167, 0.8712]
#
# Num_features : 84
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.95, 0.9222, 0.8675]
#
# Num_features : 85
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.9556, 0.9167, 0.8662]
#
# Num_features : 86
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9556, 0.9222, 0.8725]
#
# Num_features : 87
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9556, 0.9222, 0.8725]
#
# Num_features : 88
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.9611, 0.9111, 0.865]
#
# Num_features : 89
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.9611, 0.9111, 0.865]
#
# Num_features : 90
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.9556, 0.9167, 0.8662]
#
# Num_features : 91
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9556, 0.9111, 0.86]
#
# Num_features : 92
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9556, 0.9111, 0.86]
#
# Num_features : 93
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 94
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8556, 0.9444, 0.9111, 0.85]
#
# Num_features : 95
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.85, 0.9389, 0.9111, 0.845]
#
# Num_features : 96
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8556, 0.9444, 0.9111, 0.85]
#
# Num_features : 97
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8556, 0.9444, 0.9111, 0.85]
#
# Num_features : 98
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.95, 0.9167, 0.8612]
#
# Num_features : 99
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 100
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 101
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 102
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 103
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 104
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 105
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 106
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.95, 0.9111, 0.855]
#
# Num_features : 107
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8556, 0.95, 0.9056, 0.8488]
#
# Num_features : 108
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 109
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9444, 0.9167, 0.8562]
#
# Num_features : 110
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9444, 0.9222, 0.8625]
#
# Num_features : 111
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8667, 0.9389, 0.9278, 0.8637]
#
# Num_features : 112
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8611, 0.9333, 0.9278, 0.8588]
#
# Num_features : 113
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8833, 0.9444, 0.9389, 0.8812]
#
# Num_features : 114
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8833, 0.9444, 0.9389, 0.8812]
#
# Num_features : 115
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9389, 0.9389, 0.8762]
#
# Num_features : 116
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8778, 0.9389, 0.9389, 0.8762]
#
# Num_features : 117
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8722, 0.9333, 0.9389, 0.8712]
#
# Num_features : 118
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8833, 0.9333, 0.95, 0.8837]
#
# Num_features : 119
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8833, 0.9333, 0.95, 0.8837]
#
# Num_features : 120
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8889, 0.9389, 0.95, 0.8888]
#
# Num_features : 121
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8889, 0.9333, 0.9556, 0.89]
#
# Num_features : 122
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.8944, 0.9444, 0.95, 0.8938]
#
# Num_features : 123
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9556, 0.95, 0.9038]
#
# Num_features : 124
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 125
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 126
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 127
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 128
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 129
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 130
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 131
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 132
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 133
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 134
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9556, 0.95, 0.9038]
#
# Num_features : 135
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 136
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 137
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 138
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 139
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 140
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 141
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 142
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 143
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 144
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9556, 0.9611, 0.9162]
#
# Num_features : 145
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9556, 0.9611, 0.9162]
#
# Num_features : 146
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.95, 0.9611, 0.9112]
#
# Num_features : 147
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.95, 0.9611, 0.9112]
#
# Num_features : 148
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9556, 0.9556, 0.91]
#
# Num_features : 149
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9556, 0.9611, 0.9162]
#
# Num_features : 150
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9556, 0.9611, 0.9162]
#
# Num_features : 151
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 152
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 153
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 154
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 155
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 156
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 157
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9611, 0.9389, 0.8962]
#
# Num_features : 158
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9611, 0.9389, 0.8962]
#
# Num_features : 159
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 160
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 161
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 162
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 163
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 164
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9611, 0.9389, 0.8962]
#
# Num_features : 165
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9611, 0.9389, 0.8962]
#
# Num_features : 166
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 167
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 168
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 169
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9088]
#
# Num_features : 170
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9667, 0.95, 0.9138]
#
# Num_features : 171
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 172
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 173
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 174
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 175
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 176
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 177
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 178
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 179
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 180
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9611, 0.9444, 0.9025]
#
# Num_features : 181
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 182
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9556, 0.95, 0.9038]
#
# Num_features : 183
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9556, 0.95, 0.9038]
#
# Num_features : 184
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9056, 0.9556, 0.95, 0.9038]
#
# Num_features : 185
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9556, 0.9444, 0.8975]
#
# Num_features : 186
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9556, 0.9444, 0.8975]
#
# Num_features : 187
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9, 0.9556, 0.9444, 0.8975]
#
# Num_features : 188
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9556, 0.9556, 0.91]
#
# Num_features : 189
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9111, 0.9611, 0.95, 0.9087]
#
# Num_features : 190
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9278, 0.9722, 0.9556, 0.925]
#
# Num_features : 191
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9722, 0.95, 0.9188]
#
# Num_features : 192
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9667, 0.95, 0.9138]
#
# Num_features : 193
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9722, 0.95, 0.9188]
#
# Num_features : 194
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9278, 0.9722, 0.9556, 0.925]
#
# Num_features : 195
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9722, 0.95, 0.9188]
#
# Num_features : 196
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9667, 0.9556, 0.92]
#
# Num_features : 197
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9667, 0.9556, 0.92]
#
# Num_features : 198
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]
#
# Num_features : 199
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9222, 0.9611, 0.9611, 0.9212]
#
# Num_features : 200
# RidgeClassifier(alpha=0.5, solver='lsqr')
# Results :  [0.9167, 0.9611, 0.9556, 0.915]

# %%
# Results of Logestic Regression
y_value = np.reshape(results_SBK_LR,(191,4))

plot_graph(y_value[:,0],"Result with SelectKBest : Accuracy")
plot_graph(y_value[:,1],"Result with SelectKBest : Specificity")
plot_graph(y_value[:,2],"Result with SelectKBest : Sensitivity")
plot_graph(y_value[:,3],"Result with SelectKBest : AUC")
